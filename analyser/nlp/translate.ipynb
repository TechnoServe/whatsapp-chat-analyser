# %%
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 640 kB/s
# Collecting idna==2.*
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 2.1 MB/s
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.6 MB/s
# Collecting hstspreload
#   Downloading hstspreload-2021.11.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 3.0 MB/s
# Collecting chardet==3.*
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 7.9 MB/s
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /home/egide/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2021.5.30)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.0 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 3.5 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16367 sha256=7241cba293f412c3ede5f3948cc34da59f0d1f2a43298ef44701a6a03d82cf61
#   Stored in directory: /home/egide/.cache/pip/wheels/dd/59/af/8d6c96a719763990f1c548e36b17d9efdfb767f42f7ff39f53
# Successfully built googletrans
# Installing collected packages: idna, hyperframe, hpack, h2, sniffio, h11, httpcore, hstspreload, chardet, rfc3986, httpx, googletrans
#   Attempting uninstall: idna
#     Found existing installation: idna 3.2
#     Uninstalling idna-3.2:
#       Successfully uninstalled idna-3.2
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0 sniffio-1.2.0

# %%
import googletrans
from googletrans import Translator
translator = Translator()

# %%
# import the library


import pandas as pd
import numpy as np

# %%
messages = pd.read_excel('messages1.xlsx')

# %%
messages_translated = messages.copy()

# %%
messages_translated.head()
# Out:
#      Date    Time                           Author                   Message  \
# 0  1/4/20  19:34     esther marubi nyakango, dukas                Where am i
# 1  1/4/20  19:34     esther marubi nyakango, dukas     What about this group
# 2  1/4/20  19:38     esther marubi nyakango, dukas  Can somebody plz tell me
# 3  1/4/20  19:41       mariam karimi ciekou, dukas         Waithira uko uku?
# 4  1/4/20  21:07    Joseph muriithi muriuki, dukas                 I like it
#
#    Letters  Words   Intents
# 0       10      3       NaN
# 1       21      4       NaN
# 2       24      5  ask_help
# 3       17      3       NaN
# 4        9      3      like

# %%
# Out:
# 'of our video today I learned,'

# %%
for message in messages_translated['Message'].tail(10):
    trans = translator.translate(message,src='sw', dest='en').text
    print(message)
    print(trans)
# Out:
# Thanks alot goes to my teachers,may God almighty bless you all for us in this long journey of education!..
# Thanks alot goes to my teachers,may God almighty bless you all for us in this long journey of education!..
# This video chat has given me alot of advise on how I can manage my business first of all..I should have agood customer care knowing how I approach my customers wid appreciating language.
# This video chat has given me alot of advise on how I can manage my business first of all..I should have agood customer care knowing how I approach my customers wid appreciating language.
# Asante sana mwalimu
# Asante sana mwalimu
# It has also thought me to display my goods in awell organised manner that acustomer can recognise n select easily whatever she/he wants.
# It has also thought me to display my goods in awell organised manner that acustomer can recognise n select easily whatever she/he wants.
# Acustomer should have aright to whatever she's buying n should be at agood quality. ..let acustomer live when she/he appreciates the service offered in the shop!.it's I should consider always!.
# Acustomer should have aright to whatever she's buying n should be at agood quality. ..let acustomer live when she/he appreciates the service offered in the shop!.it's I should consider always!.
# I should always have time to speak to my customers knowing their recommendation on my business service I offer to them..it's very important to my business n thanks alot for this important notes!.
# I should always have time to speak to my customers knowing their recommendation on my business service I offer to them..it's very important to my business n thanks alot for this important notes!.
# This video has taught me a lot,if you have good relationship with your customers your sales will increase hence your profit too.once you create good relationship with your customers, they will always come back with their friends.
# This video has taught me a lot,if you have good relationship with your customers your sales will increase hence your profit too.once you create good relationship with your customers, they will always come back with their friends.
# Kwa video yetu ya leo nimejifunza,njisi ya kuudumia wateja wangu hata wale wakorofi Kwa maana wote wanaumuhimu kwangu,na kuwa na lugha nzuri Kwa wote na pia kufunza wafanyikazi njinzi ya kuwaudumia kwa heshima
# Kwa video yetu ya leo nimejifunza,njisi ya kuudumia wateja wangu hata wale wakorofi Kwa maana wote wanaumuhimu kwangu,na kuwa na lugha nzuri Kwa wote na pia kufunza wafanyikazi njinzi ya kuwaudumia kwa heshima
# Habari  zenu  said Niko mama oc wiki mbili Sasa  hata kusoma masomo ya vzr sipati lakiniktuko pamoja
# Habari  zenu  said Niko mama oc wiki mbili Sasa  hata kusoma masomo ya vzr sipati lakiniktuko pamoja
# Pole sana saumu mungu atampa uponyaji
# Pole sana saumu mungu atampa uponyaji

# %%
import copy
translatedList = []
for index, row in messages_translated.iterrows():
    # REINITIALIZE THE API
    translator = Translator()
    newrow = copy.deepcopy(row)
    try:
        # translate the 'text' column
        translated = translator.translate(row['Message'],src='sw', dest='en')
        newrow['translated'] = translated.text
        # print(translated.text)
    except Exception as e:
        print(str(e))
        continue
    translatedList.append(newrow)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3276/405789476.py in <module>
#       7     try:
#       8         # translate the 'text' column
# ----> 9         translated = translator.translate(row['Message'],src='sw', dest='en')
#      10         newrow['translated'] = translated.text
#      11         # print(translated.text)
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/googletrans/client.py in translate(self, text, dest, src, **kwargs)
#     208
#     209         origin = text
# --> 210         data, response = self._translate(text, dest, src, kwargs)
#     211
#     212         # this code will be updated when the format is changed.
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/googletrans/client.py in _translate(self, text, dest, src, override)
#     106
#     107         url = urls.TRANSLATE.format(host=self._pick_service_url())
# --> 108         r = self.client.get(url, params=params)
#     109
#     110         if r.status_code == 200:
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpx/_client.py in get(self, url, params, headers, cookies, auth, allow_redirects, timeout)
#     753         timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     754     ) -> Response:
# --> 755         return self.request(
#     756             "GET",
#     757             url,
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpx/_client.py in request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     598             cookies=cookies,
#     599         )
# --> 600         return self.send(
#     601             request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602         )
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpx/_client.py in send(self, request, stream, auth, allow_redirects, timeout)
#     618         auth = self.build_auth(request, auth)
#     619
# --> 620         response = self.send_handling_redirects(
#     621             request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622         )
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpx/_client.py in send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     645                 raise TooManyRedirects()
#     646
# --> 647             response = self.send_handling_auth(
#     648                 request, auth=auth, timeout=timeout, history=history
#     649             )
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpx/_client.py in send_handling_auth(self, request, history, auth, timeout)
#     682         request = next(auth_flow)
#     683         while True:
# --> 684             response = self.send_single_request(request, timeout)
#     685             if auth.requires_response_body:
#     686                 response.read()
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpx/_client.py in send_single_request(self, request, timeout)
#     712                 headers,
#     713                 stream,
# --> 714             ) = transport.request(
#     715                 request.method.encode(),
#     716                 request.url.raw,
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py in request(self, method, url, headers, stream, timeout)
#     150
#     151             try:
# --> 152                 response = connection.request(
#     153                     method, url, headers=headers, stream=stream, timeout=timeout
#     154                 )
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpcore/_sync/connection.py in request(self, method, url, headers, stream, timeout)
#      76             "connection.request method=%r url=%r headers=%r", method, url, headers
#      77         )
# ---> 78         return self.connection.request(method, url, headers, stream, timeout)
#      79
#      80     def _open_socket(self, timeout: TimeoutDict = None) -> SyncSocketStream:
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpcore/_sync/http2.py in request(self, method, url, headers, stream, timeout)
#     116             self.streams[stream_id] = h2_stream
#     117             self.events[stream_id] = []
# --> 118             return h2_stream.request(method, url, headers, stream, timeout)
#     119         except Exception:
#     120             self.max_streams_semaphore.release()
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpcore/_sync/http2.py in request(self, method, url, headers, stream, timeout)
#     290
#     291         # Receive the response.
# --> 292         status_code, headers = self.receive_response(timeout)
#     293         reason_phrase = get_reason_phrase(status_code)
#     294         stream = SyncByteStream(
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpcore/_sync/http2.py in receive_response(self, timeout)
#     342         """
#     343         while True:
# --> 344             event = self.connection.wait_for_event(self.stream_id, timeout)
#     345             if isinstance(event, h2.events.ResponseReceived):
#     346                 break
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpcore/_sync/http2.py in wait_for_event(self, stream_id, timeout)
#     195         with self.read_lock:
#     196             while not self.events[stream_id]:
# --> 197                 self.receive_events(timeout)
#     198         return self.events[stream_id].pop(0)
#     199
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpcore/_sync/http2.py in receive_events(self, timeout)
#     202         Read some data from the network, and update the H2 state.
#     203         """
# --> 204         data = self.socket.read(self.READ_NUM_BYTES, timeout)
#     205         events = self.h2_state.receive_data(data)
#     206         for event in events:
#
# ~/Documents/TechnoServe/whatsapp-chat-analyser/env/lib/python3.8/site-packages/httpcore/_backends/sync.py in read(self, n, timeout)
#      60             with map_exceptions(exc_map):
#      61                 self.sock.settimeout(read_timeout)
# ---> 62                 return self.sock.recv(n)
#      63
#      64     def write(self, data: bytes, timeout: TimeoutDict) -> None:
#
# /usr/lib/python3.8/ssl.py in recv(self, buflen, flags)
#    1224                     "non-zero flags not allowed in calls to recv() on %s" %
#    1225                     self.__class__)
# -> 1226             return self.read(buflen)
#    1227         else:
#    1228             return super().recv(buflen, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1099                 return self._sslobj.read(len, buffer)
#    1100             else:
# -> 1101                 return self._sslobj.read(len)
#    1102         except SSLError as x:
#    1103             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
pd.DataFrame(translatedList)
# Out:
#          Date    Time                           Author  \
# 0      1/4/20  19:34     esther marubi nyakango, dukas
# 1      1/4/20  19:34     esther marubi nyakango, dukas
# 2      1/4/20  19:38     esther marubi nyakango, dukas
# 3      1/4/20  19:41       mariam karimi ciekou, dukas
# 4      1/4/20  21:07    Joseph muriithi muriuki, dukas
# ...       ...     ...                              ...
# 3276  2/29/20  14:18                   Chris Bc Uthiru
# 3277  2/29/20  14:18                   +254 725 855323
# 3278  2/29/20  14:19                   Chris Bc Uthiru
# 3279  2/29/20  14:21                   Chris Bc Uthiru
# 3280  2/29/20  14:26                   Chris Bc Uthiru
#
#                                                 Message  Letters  Words  \
# 0                                            Where am i       10      3
# 1                                 What about this group       21      4
# 2                              Can somebody plz tell me       24      5
# 3                                     Waithira uko uku?       17      3
# 4                                             I like it        9      3
# ...                                                 ...      ...    ...
# 3276  *From now henceforth @254110131396 , is your t...      219     44
# 3277  when my temperatures boil u don hv to jump int...      187     38
# 3278  I followed you up on DM & you are saying nikut...       98     22
# 3279  *Let us Learn to Respect the leaders we have,...*       49      9
# 3280  I never meant u @254725855323 , am just giving...      122     23
#
#        Intents                                         translated
# 0          NaN                                         Where am i
# 1          NaN                              What about this group
# 2     ask_help                           Can somebody plz tell me
# 3          NaN                                  Waithira uko uku?
# 4         like                                          I like it
# ...        ...                                                ...
# 3276       NaN  *From now henceforth @254110131396 , is your t...
# 3277       NaN  when my temperatures boil u don hv to jump int...
# 3278       NaN  I followed you up on DM & you are saying nikut...
# 3279       NaN  *Let us Learn to Respect the leaders we have,...*
# 3280       NaN  I never meant u @254725855323 , am just giving...
#
# [3281 rows x 8 columns]

# %%
short_translation = pd.DataFrame(translatedList)

# %%
short_translation
# Out:
#        Date    Time                           Author  \
# 0    1/4/20  19:34     esther marubi nyakango, dukas
# 1    1/4/20  19:34     esther marubi nyakango, dukas
# 2    1/4/20  19:38     esther marubi nyakango, dukas
# 3    1/4/20  19:41       mariam karimi ciekou, dukas
# 4    1/4/20  21:07    Joseph muriithi muriuki, dukas
# ..      ...     ...                              ...
# 587  2/3/20  14:34      emelda nyambura thoni, dukas
# 588  2/3/20  14:43       sarah wanjiru nduine, dukas
# 589  2/3/20  17:10      mercy nyokabi karanja, dukas
# 590  2/3/20  17:18      mercy nyokabi karanja, dukas
# 591  2/3/20  17:37           paul thuo kimani, dukas
#
#                                                Message  Letters  Words  \
# 0                                           Where am i       10      3
# 1                                What about this group       21      4
# 2                             Can somebody plz tell me       24      5
# 3                                    Waithira uko uku?       17      3
# 4                                            I like it        9      3
# ..                                                 ...      ...    ...
# 587                               Okay sawa nitangonja       20      3
# 588                             Not yet,sijapata bado.       22      3
# 589  Merchandising refers to promotion of goods/ se...       96     15
# 590  Merchandising refers to promotion of goods/ se...       71     10
# 591  Is a selling of varieties in a large quantity ...       72     13
#
#       Intents                                         translated
# 0         NaN                                         Where am i
# 1         NaN                              What about this group
# 2    ask_help                           Can somebody plz tell me
# 3         NaN                         Did you pour it over here?
# 4        like                                          I like it
# ..        ...                                                ...
# 587       NaN                               Okay sawa nitangonja
# 588       NaN                             Not yet,sijapata bado.
# 589       NaN  Merchandising refers to promotion of goods/ se...
# 590       NaN  Merchandising refers to promotion of goods/ se...
# 591       NaN  Is a selling of varieties in a large quantity ...
#
# [592 rows x 8 columns]

# %%
import random
import json
import subprocess
import time
listofservers = ["South Africa", "Egypt" , "Australia", "New Zealand",  "South Korea", "Singapore", "Taiwan", "Vietnam", "Hong Kong", "Indonesia", "Thailand", "Japan", "Malaysia", "United Kingdom", "Netherlands", "Germany", "France", "Belgium", "Switzerland", "Sweden","Spain","Denmark", "Italy", "Norway", "Austria", "Romania", "Czech Republic", "Luxembourg", "Poland", "Finland", "Hungary", "Latvia", "Russia", "Iceland", "Bulgaria", "Croatia", "Moldova", "Portugal", "Albania", "Ireland", "Slovakia","Ukraine", "Cyprus", "Estonia", "Georgia", "Greece", "Serbia", "Slovenia", "Azerbaijan", "Bosnia and Herzegovina", "Macedonia","India", 'Turkey', 'Israel', 'United Arab Emirates', 'United States', 'Canada','Mexico'
,"Brazil", "Costa Rica", "Argentina", "Chile"]


def SelectServer(l):
    return random.choice(l)

def translate_text(text, dest_language="en"):  
    # Used to translate using the googletrans library
    translator = googletrans.Translator()
    try:

        translation = translator.translate(text=text, src='sw', dest=dest_language)

    except json.decoder.JSONDecodeError:
        # api call restriction

        print("exception !! déconection du VPN ")
        process = subprocess.Popen(["nordvpn", "-d"], shell = True ,stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        process.wait()

        time.sleep(5)

        srv = SelectServer(listofservers)

        print("sélection du serveur  : "+ srv + " et connexion")

        process = subprocess.Popen(["nordvpn", "-c", "-g", srv ], shell = True ,stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        process.wait()
        time.sleep(60)

        return translate_text(text=text, dest_language=dest_language)

    return translation.text

# %%
#translate to EN and remove EN stopwords 
ListCapTranslated = []
for row  in ListCaptionsCleanFiltred:
    # REINITIALIZE THE API
    newrow = translate_text(row, dest_language="en")
    ListCapTranslated.append(newrow)

# %%
ListCapTranslated
